# %% [markdown]
# ### 食用/毒キノコの非線形分類
# <b>
# 氏名：鍋 知宏<br>
# kaggleか<br>
# 【kaggle課題】<br>
# Mushroom Classification<br>
# https://www.kaggle.com/uciml/mushroom-classification/data
#
# <br>
# 【課題内容】<br>
# キノコの特徴を表すデータセット内において、どの特徴が色であることを示し、<br>
# どの特徴が毒であることを示すのかを提示する。<br>
# <br>
# 【宿題】
# 1. 課題のページからデータをダウンロードする。<br>
# 2. 目的変数を答える。<br>
# 3. 目的変数と説明変数の関係を確認するためのグラフを作成する。<br>
# 4. 目的変数を説明するのに有効そうな説明変数を見つけ、有効と考える説明変数に順位をつける。<br>
# </b>

# %%
import pandas as pd
import numpy as np
from IPython.display import display
from dateutil.parser import parse
import matplotlib.pyplot as plt
from collections import OrderedDict
import seaborn as sns

# %% [markdown]
# ### 属性情報
# まずは、kaggle課題サイトの属性情報を見やすいように日本語にして眺めてみました。

# %%
lang_trans = {
    'classes':'分類クラス',
    'cap-shape':'かさの形状',
    'cap-surface':'かさの表面',
    'cap-color':'かさの色',
    'bruises':'きず',
    'odor':'におい',
    'gill-attachment':'ひだのつき方',
    'gill-spacing':'ひだの間隔',
    'gill-size':'ひだのサイズ',
    'gill-color':'ひだの色',
    'stalk-shape':'柄の形状',
    'stalk-root':'柄の根本',
    'stalk-surface-above-ring':'柄の表面(つばの上方部)',
    'stalk-surface-below-ring':'柄の表面(つばの下方部)',
    'stalk-color-above-ring':'柄の色(つばの上方部)',
    'stalk-color-below-ring':'柄の色(つばの下方部)',
    'veil-type':'つぼのタイプ',
    'veil-color':'つぼの色',
    'ring-number':'つばの数',
    'ring-type':'つばのタイプ',
    'spore-print-color':'胞子紋の色',
    'population':'集団形成',
    'habitat':'生息地'
}
data_items = {
    'classes':{'e':'食用キノコ', 'p':'毒キノコ'},
    'cap-shape':{'b':'ベル型', 'c':'円錐型', 'x':'饅頭型','f':'扁平型', 'k':'こぶ型', 's':'凹型'},
    'cap-surface':{'f':'繊維状', 'g':'溝状', 'y':'鱗片状', 's':'平滑状'},
    'cap-color':{'n':'茶色', 'b':'淡黄色', 'c':'シナモン色', 'g':'灰色', 'r':'緑色', 'p':'ピンク色', 'u':'紫色', 'e':'赤色'},
    'bruises':{'t':'あり', 'n':'なし'},
    'odor':{'a':'アーモンド臭', 'l':'アニス臭', 'c':'クレオソート臭', 'y':'魚臭', 'f':'悪臭', 'm':'かび臭', 'n':'無臭', 'p':'刺激臭', 's':'スパイシー臭',},
    'gill-attachment':{'a':'直性', 'd':'垂性', 'f':'離生', 'n':'湾生'},
    'gill-spacing':{'c':'近い', 'w':'密な', 'd':'遠い'},
    'gill-size':{'b':'広い', 'n':'狭い'},
    'gill-color':{'k':'黒色', 'n':'茶色', 'b':'淡黄色', 'h':'チョコレート色', 'g':'灰色', 'r':'緑色', 'o':'オレンジ色', 'p':'ピンク色', 'u':'紫色', 'e':'赤色', 'w':'白色', 'y':'黄色'},
    'stalk-shape':{'e':'先太型', 't':'先細型'},
    'stalk-root':{'b':'球根状', 'c':'棍棒状', 'u':'カップ状', 'e':'扁平状', 'z':'根状菌糸束', 'r':'根状', '?':'欠損値'},
    'stalk-surface-above-ring':{'f':'繊維状', 'y':'鱗片状', 'k':'絹状', 's':'平滑状'},
    'stalk-surface-below-ring':{'f':'繊維状', 'y':'鱗片状', 'k':'絹状', 's':'平滑状'},
    'stalk-color-above-ring':{'n':'茶色', 'b':'淡黄色', 'c':'シナモン色', 'g':'灰色', 'o':'オレンジ色', 'p':'ピンク色', 'e':'赤色', 'w':'白色', 'y':'黄色'},
    'stalk-color-below-ring':{'n':'茶色', 'b':'淡黄色', 'c':'シナモン色', 'g':'灰色', 'o':'オレンジ色', 'p':'ピンク色', 'e':'赤色', 'w':'白色', 'y':'黄色'},
    'veil-type':{'p':'部分型', 'u':'全体型'},
    'veil-color':{'n':'茶色', 'o':'オレンジ色', 'w':'白色', 'y':'黄色'},
    'ring-number':{'n':'なし', 'o':'1', 't':'2'},
    'ring-type':{'c':'クモの巣型', 'e':'一過型', 'f':'口広がり型', 'l':'大型', 'n':'なし', 'p':'ペンダント型', 's':'被覆型', 'z':'ゾーン型'},
    'spore-print-color':{'k':'黒色', 'n':'茶色', 'b':'淡黄色', 'h':'チョコレート色', 'r':'緑色', 'o':'オレンジ色', 'u':'紫色', 'w':'白色', 'y':'黄色'},
    'population':{'a':'豊富', 'c':'群生', 'n':'多数', 's':'散在', 'v':'少数', 'y':'単性'},
    'habitat':{'g':'芝生', 'l':'葉', 'm':'牧草地', 'p':'道路', 'u':'都市部', 'w':'廃棄物', 'd':'木'}
}

item_max_size = max([len(x) for x in data_items.values()])
data_set = OrderedDict()
for feature, items in data_items.items():
    key_feature = '{0}({1})'.format(feature, lang_trans[feature])
    data_set[key_feature] = []
    for label, item in items.items():
        value_item = "{0}({1})".format(label, item)
        data_set[key_feature].append(value_item)
    if len(data_set[key_feature]) < item_max_size:
        for i in enumerate(range(item_max_size - len(data_set[key_feature]))):
            data_set[key_feature].append('') 
data_set = pd.DataFrame.from_dict(data_set).T
data_set = data_set.style.set_properties(**{'text-align': 'left'})
display(data_set)
# Out:
# <style  type="text/css" >
#     #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow0_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow1_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow2_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow3_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow4_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow5_col11 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col0 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col1 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col2 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col3 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col4 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col5 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col6 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col7 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col8 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col9 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col10 {
#             text-align:  left;
#         }    #T_2a980618_053d_11e8_a4ec_f82819a014barow6_col11 {
#             text-ali

# %% [markdown]
# ### 属性情報からわかること
# <b>
# ・本課題はキノコが食用キノコか毒キノコかの識別であるため、目的変数はclassesとなる。<br>
# ・属性要素はすべてアルファベット１文字のString型である。<br>
# ・属性『stalk-root(柄の根本)』の"?"は欠損値である。<br>
# ・各属性の要素は概ね独立性があり、名寄せの必要なさそうである。<br>
# </b>

# %% [markdown]
# ### データ読込

# %%
df_data = pd.read_csv("mushrooms.csv")
display(df_data)
data_size = len(df_data)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# 12       e         b           s         y       t    a               f
# 13       p         x           y         w       t    p               f
# 14       e         x           f         n       f    n               f
# 15       e         s           f         g       f    n               f
# 16       e         f           f         w       f    n               f
# 17       p         x           s         n       t    p               f
# 18       p         x           y         w       t    p               f
# 19       p         x           s         n       t    p               f
# 20       e         b           s         y       t    a               f
# 21       p         x           y         n       t    p               f
# 22       e         b           y         y       t    l               f
# 23       e         b           y         w       t    a               f
# 24       e         b           s         w       t    l               f
# 25       p         f           s         w       t    p               f
# 26       e         x           y         y       t    a               f
# 27       e         x           y         w       t    l               f
# 28       e         f           f         n       f    n               f
# 29       e         x           s         y       t    a               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8094     e         b           s         g       f    n               f
# 8095     p         x           y         c       f    m               f
# 8096     e         k           f         w       f    n               f
# 8097     p         k           y         n       f    s               f
# 8098     p         k           s         e       f    y               f
# 8099     e         k           f         w       f    n               f
# 8100     e         f           s         n       f    n               a
# 8101     p         k           s         e       f    s               f
# 8102     e         x           s         n       f    n               a
# 8103     e         k           s         n       f    n               a
# 8104     e         k           s         n       f    n               a
# 8105     e         k           s         n       f    n               a
# 8106     e         k           s         n       f    n               a
# 8107     e         x           s         n       f    n               a
# 8108     p         k           y         e       f    y               f
# 8109     e         b           s         w       f    n               f
# 8110     e         x           s         n       f    n               a
# 8111     e         k           s         w       f    n               f
# 8112     e         k           s         n       f    n               a
# 8113     p         k           y         e       f    y               f
# 8114     p         f           y         c       f    m               a
# 8115     e         x           s         n       f    n               a
# 8116     p         k           y         n       f    s               f
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0               c         n          k   ...                          s
# 1               c         b          k   ...                          s
# 2               c         b          n   ...                          s
# 3               c         n          n   ...                          s
# 4               w         b          k   ...                          s
# 5               c         b          n   ...                          s
# 6               c         b          g   ...                          s
# 7               c         b          n   ...                          s
# 8               c         n          p   ...                          s
# 9               c         b          g   ...                          s
# 10              c         b          g   ...                          s
# 11              c         b          n   ...                          s
# 12              c         b          w   ...                          s
# 13              c         n          k   ...                          s
# 14              w         b          n   ...                          f
# 15              c         n          k   ...                          s
# 16              w         b          k   ...                          s
# 17              c         n          n   ...                          s
# 18              c         n          n   ...                          s
# 19              c         n          k   ...                          s
# 20              c         b          k   ...                          s
# 21              c         n          n   ...                          s
# 22              c         b          k   ...                          s
# 23              c         b          w   ...                          s
# 24              c         b          g   ...                          s
# 25              c         n          n   ...                          s
# 26              c         b          n   ...                          s
# 27              c         b          w   ...                          s
# 28              c         n          k   ...                          s
# 29              w         n          n   ...                          s
# ...           ...       ...        ...   ...                        ...
# 8094            w         b          g   ...                          s
# 8095            c         b          y   ...                          y
# 8096            w         b          w   ...                          s
# 8097            c         n          b   ...                          k
# 8098            c         n          b   ...                          k
# 8099            w         b          w   ...                          k
# 8100            c         b          o   ...                          s
# 8101            c         n          b   ...                          s
# 8102            c         b          y   ...                          s
# 8103            c         b          y   ...                          s
# 8104            c         b          y   ...                          s
# 8105            c         b          y   ...                          s
# 8106            c         b          o   ...                          s
# 8107            c         b          y   ...                          s
# 8108            c         n          b   ...                          s
# 8109            w         b          w   ...                          s
# 8110            c         b          o   ...                          s
# 8111            w         b          p   ...                          s
# 8112            c         b          o   ...                          s
# 8113            c         n          b   ...                          k
# 8114            c         b          y   ...                          y
# 8115            c         b          y   ...                          s
# 8116            c         n          b   ...                          k
# 8117            c         n          b   ...                          s
# 8118            c         n          b   ...                          s
# 8119            c         b          y   ...                          s
# 8120            c         b          y   ...                          s
# 8121            c         b          n   ...                          s
# 8122            c         n          b   ...                          k
# 8123            c         b          y   ...                          s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# 5                         w                      w         p          w
# 6                         w                      w         p          w
# 7                         w                      w         p          w
# 8                         w                      w         p          w
# 9                         w                      w         p          w
# 10                        w                      w         p          w
# 11                        w                      w         p          w
# 12                        w                      w         p          w
# 13                        w                      w         p          w
# 14                        w                      w         p          w
# 15                        w                      w         p          w
# 16                        w                      w         p          w
# 17                        w                      w         p          w
# 18                        w                      w         p          w
# 19                        w                      w         p          w
# 20                        w                      w         p          w
# 21                        w                      w         p          w
# 22                        w                      w         p          w
# 23                        w                      w         p          w
# 24                        w                      w         p          w
# 25                        w                      w         p          w
# 26                        w                      w         p          w
# 27                        w                      w         p          w
# 28                        w                      w         p          w
# 29                        w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8094                      w                      w         p          w
# 8095                      c                      c         p          w
# 8096                      w                      w         p          w
# 8097                      p                      p         p          w
# 8098                      w                      p         p          w
# 8099                      w                      w         p          w
# 8100                      o                      o         p          n
# 8101                      p                      w         p          w
# 8102                      o                      o         p          n
# 8103                      o                      o         p          n
# 8104                      o                      o         p          o
# 8105                      o                      o         p          n
# 8106                      o                      o         p          o
# 8107                      o                      o         p          o
# 8108                      p                      w         p          w
# 8109                      w                      w         p          w
# 8110                      o                      o         p          o
# 8111                      w                      w         p          w
# 8112                      o                      o         p          n
# 8113                      p                      p         p          w
# 8114                      c                      c         p          w
# 8115                      o                      o         p          o
# 8116                      p                      w         p          w
# 8117                      p                      w         p          w
# 8118                      p                      w         p          w
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# 5              o         p                 k          n       g
# 6              o         p                 k          n       m
# 7              o         p                 n          s       m
# 8              o         p                 k          v       g
# 9              o         p                 k          s       m
# 10             o         p                 n          n       g
# 11             o         p                 k          s       m
# 12             o         p                 n          s       g
# 13             o         p                 n          v       u
# 14             o         e                 k          a       g
# 15             o         p                 n          y       u
# 16             o         e                 n          a       g
# 17             o         p                 k          s       g
# 18             o         p                 n          s       u
# 19             o         p                 n          s       u
# 20             o         p                 n          s       m
# 21             o         p                 n          v       g
# 22             o         p                 n          s       m
# 23             o         p                 n          n       m
# 24             o         p                 k          s       m
# 25             o         p                 n          v       g
# 26             o         p                 n          n       m
# 27             o         p                 n          n       m
# 28             o         p                 k          y       u
# 29             o         p                 n          v       d
# ...          ...       ...               ...        ...     ...
# 8094           t         p                 w          n       g
# 8095           n         n                 w          c       d
# 8096           t         p                 w          n       g
# 8097           o         e                 w          v       l
# 8098           o         e                 w          v       d
# 8099           t         p                 w          s       g
# 8100           o         p                 b          v       l
# 8101           o         e                 w          v       p
# 8102           o         p                 n          c       l
# 8103           o         p                 o          c       l
# 8104           o         p                 n          v       l
# 8105           o         p                 y          v       l
# 8106           o         p                 n          v       l
# 8107           o         p                 n          c       l
# 8108           o         e                 w          v       l
# 8109           t         p                 w          n       g
# 8110           o         p                 n          v       l
# 8111           t         p                 w          n       g
# 8112           o         p                 b          v       l
# 8113           o         e                 w          v       d
# 8114           n         n                 w          c       d
# 8115           o         p                 o          v       l
# 8116           o         e                 w          v       l
# 8117           o         e                 w          v       d
# 8118           o         e                 w          v       d
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %% [markdown]
# ### 欠損値の確認
# 属性『stalk-root(柄の根本)』の欠損値は"?"でラベリングされているが、その他にデータがNullのレコードがないか確認する。

# %%
pd.concat([df_data.describe().T, pd.DataFrame(df_data.isnull().sum(), columns=["num of missing"])], axis=1)
# Out:
#                          count unique top  freq  num of missing
# class                     8124      2   e  4208               0
# cap-shape                 8124      6   x  3656               0
# cap-surface               8124      4   y  3244               0
# cap-color                 8124     10   n  2284               0
# bruises                   8124      2   f  4748               0
# odor                      8124      9   n  3528               0
# gill-attachment           8124      2   f  7914               0
# gill-spacing              8124      2   c  6812               0
# gill-size                 8124      2   b  5612               0
# gill-color                8124     12   b  1728               0
# stalk-shape               8124      2   t  4608               0
# stalk-root                8124      5   b  3776               0
# stalk-surface-above-ring  8124      4   s  5176               0
# stalk-surface-below-ring  8124      4   s  4936               0
# stalk-color-above-ring    8124      9   w  4464               0
# stalk-color-below-ring    8124      9   w  4384               0
# veil-type                 8124      1   p  8124               0
# veil-color                8124      4   w  7924               0
# ring-number               8124      3   o  7488               0
# ring-type                 8124      5   p  3968               0
# spore-print-color         8124      9   w  2388               0
# population                8124      6   v  4040               0
# habitat                   8124      7   d  3148               0

# %% [markdown]
# Nullデータは存在しないことがわかる。

# %% [markdown]
# ### 目的変数と説明変数の関係
# 各クラスに対し、各属性の要素がどの程度のデータ量をしめているのが可視化する。

# %%
dict_p = {}
for col in df_data.columns:
    if col=="class":
        continue
    print('*========================================================================*')
    print('{0}({1})'.format(col, lang_trans[col]))
    for item, value in data_items[col].items():
        print('{0}:{1}, '.format(item, value), end='')
    print()
    print('*========================================================================*')
    df_c = pd.crosstab(index=[df_data["class"]], columns=df_data[col],margins=True)
    display(df_c)
    df_c = df_c / data_size
    dict_p[col] = df_c.copy()
    df_dis = df_c.copy()
    display(df_dis.style.format("{:.2%}"))
    df_dis.plot.bar()
    plt.show()
# Out:
# *========================================================================*
# cap-shape(かさの形状)
# b:ベル型, c:円錐型, x:饅頭型, f:扁平型, k:こぶ型, s:凹型,
# *========================================================================*
# cap-shape    b  c     f    k   s     x   All
# class
# e          404  0  1596  228  32  1948  4208
# p           48  4  1556  600   0  1708  3916
# All        452  4  3152  828  32  3656  8124
# <style  type="text/css" >
# </style>
# <table id="T_2ad15208_053d_11e8_b54e_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >cap-shape</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >c</th>
#         <th class="col_heading level0 col2" >f</th>
#         <th class="col_heading level0 col3" >k</th>
#         <th class="col_heading level0 col4" >s</th>
#         <th class="col_heading level0 col5" >x</th>
#         <th class="col_heading level0 col6" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2ad15208_053d_11e8_b54e_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col0" class="data row0 col0" >4.97%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col1" class="data row0 col1" >0.00%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col2" class="data row0 col2" >19.65%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col3" class="data row0 col3" >2.81%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col4" class="data row0 col4" >0.39%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col5" class="data row0 col5" >23.98%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow0_col6" class="data row0 col6" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2ad15208_053d_11e8_b54e_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col0" class="data row1 col0" >0.59%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col1" class="data row1 col1" >0.05%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col2" class="data row1 col2" >19.15%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col3" class="data row1 col3" >7.39%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col4" class="data row1 col4" >0.00%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col5" class="data row1 col5" >21.02%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow1_col6" class="data row1 col6" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2ad15208_053d_11e8_b54e_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col0" class="data row2 col0" >5.56%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col1" class="data row2 col1" >0.05%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col2" class="data row2 col2" >38.80%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col3" class="data row2 col3" >10.19%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col4" class="data row2 col4" >0.39%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col5" class="data row2 col5" >45.00%</td>
#         <td id="T_2ad15208_053d_11e8_b54e_f82819a014barow2_col6" class="data row2 col6" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# cap-surface(かさの表面)
# f:繊維状, g:溝状, y:鱗片状, s:平滑状,
# *========================================================================*
# cap-surface     f  g     s     y   All
# class
# e            1560  0  1144  1504  4208
# p             760  4  1412  1740  3916
# All          2320  4  2556  3244  8124
# <style  type="text/css" >
# </style>
# <table id="T_2afbda6e_053d_11e8_b41a_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >cap-surface</th>
#         <th class="col_heading level0 col0" >f</th>
#         <th class="col_heading level0 col1" >g</th>
#         <th class="col_heading level0 col2" >s</th>
#         <th class="col_heading level0 col3" >y</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2afbda6e_053d_11e8_b41a_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow0_col0" class="data row0 col0" >19.20%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow0_col1" class="data row0 col1" >0.00%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow0_col2" class="data row0 col2" >14.08%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow0_col3" class="data row0 col3" >18.51%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow0_col4" class="data row0 col4" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2afbda6e_053d_11e8_b41a_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow1_col0" class="data row1 col0" >9.35%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow1_col1" class="data row1 col1" >0.05%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow1_col2" class="data row1 col2" >17.38%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow1_col3" class="data row1 col3" >21.42%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow1_col4" class="data row1 col4" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2afbda6e_053d_11e8_b41a_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow2_col0" class="data row2 col0" >28.56%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow2_col1" class="data row2 col1" >0.05%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow2_col2" class="data row2 col2" >31.46%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow2_col3" class="data row2 col3" >39.93%</td>
#         <td id="T_2afbda6e_053d_11e8_b41a_f82819a014barow2_col4" class="data row2 col4" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# cap-color(かさの色)
# n:茶色, b:淡黄色, c:シナモン色, g:灰色, r:緑色, p:ピンク色, u:紫色, e:赤色,
# *========================================================================*
# cap-color    b   c     e     g     n    p   r   u     w     y   All
# class
# e           48  32   624  1032  1264   56  16  16   720   400  4208
# p          120  12   876   808  1020   88   0   0   320   672  3916
# All        168  44  1500  1840  2284  144  16  16  1040  1072  8124
# <style  type="text/css" >
# </style>
# <table id="T_2b1ac214_053d_11e8_9d7d_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >cap-color</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >c</th>
#         <th class="col_heading level0 col2" >e</th>
#         <th class="col_heading level0 col3" >g</th>
#         <th class="col_heading level0 col4" >n</th>
#         <th class="col_heading level0 col5" >p</th>
#         <th class="col_heading level0 col6" >r</th>
#         <th class="col_heading level0 col7" >u</th>
#         <th class="col_heading level0 col8" >w</th>
#         <th class="col_heading level0 col9" >y</th>
#         <th class="col_heading level0 col10" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2b1ac214_053d_11e8_9d7d_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col0" class="data row0 col0" >0.59%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col1" class="data row0 col1" >0.39%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col2" class="data row0 col2" >7.68%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col3" class="data row0 col3" >12.70%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col4" class="data row0 col4" >15.56%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col5" class="data row0 col5" >0.69%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col6" class="data row0 col6" >0.20%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col7" class="data row0 col7" >0.20%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col8" class="data row0 col8" >8.86%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col9" class="data row0 col9" >4.92%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow0_col10" class="data row0 col10" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2b1ac214_053d_11e8_9d7d_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col0" class="data row1 col0" >1.48%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col1" class="data row1 col1" >0.15%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col2" class="data row1 col2" >10.78%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col3" class="data row1 col3" >9.95%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col4" class="data row1 col4" >12.56%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col5" class="data row1 col5" >1.08%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col6" class="data row1 col6" >0.00%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col7" class="data row1 col7" >0.00%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col8" class="data row1 col8" >3.94%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col9" class="data row1 col9" >8.27%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow1_col10" class="data row1 col10" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2b1ac214_053d_11e8_9d7d_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col0" class="data row2 col0" >2.07%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col1" class="data row2 col1" >0.54%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col2" class="data row2 col2" >18.46%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col3" class="data row2 col3" >22.65%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col4" class="data row2 col4" >28.11%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col5" class="data row2 col5" >1.77%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col6" class="data row2 col6" >0.20%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col7" class="data row2 col7" >0.20%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col8" class="data row2 col8" >12.80%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col9" class="data row2 col9" >13.20%</td>
#         <td id="T_2b1ac214_053d_11e8_9d7d_f82819a014barow2_col10" class="data row2 col10" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# bruises(きず)
# t:あり, n:なし,
# *========================================================================*
# bruises     f     t   All
# class
# e        1456  2752  4208
# p        3292   624  3916
# All      4748  3376  8124
# <style  type="text/css" >
# </style>
# <table id="T_2b41ecd2_053d_11e8_9b58_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >bruises</th>
#         <th class="col_heading level0 col0" >f</th>
#         <th class="col_heading level0 col1" >t</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2b41ecd2_053d_11e8_9b58_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow0_col0" class="data row0 col0" >17.92%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow0_col1" class="data row0 col1" >33.87%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow0_col2" class="data row0 col2" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2b41ecd2_053d_11e8_9b58_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow1_col0" class="data row1 col0" >40.52%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow1_col1" class="data row1 col1" >7.68%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow1_col2" class="data row1 col2" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2b41ecd2_053d_11e8_9b58_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow2_col0" class="data row2 col0" >58.44%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow2_col1" class="data row2 col1" >41.56%</td>
#         <td id="T_2b41ecd2_053d_11e8_9b58_f82819a014barow2_col2" class="data row2 col2" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# odor(におい)
# a:アーモンド臭, l:アニス臭, c:クレオソート臭, y:魚臭, f:悪臭, m:かび臭, n:無臭, p:刺激臭, s:スパイシー臭,
# *========================================================================*
# odor     a    c     f    l   m     n    p    s    y   All
# class
# e      400    0     0  400   0  3408    0    0    0  4208
# p        0  192  2160    0  36   120  256  576  576  3916
# All    400  192  2160  400  36  3528  256  576  576  8124
# <style  type="text/css" >
# </style>
# <table id="T_2b5bc7ee_053d_11e8_8216_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >odor</th>
#         <th class="col_heading level0 col0" >a</th>
#         <th class="col_heading level0 col1" >c</th>
#         <th class="col_heading level0 col2" >f</th>
#         <th class="col_heading level0 col3" >l</th>
#         <th class="col_heading level0 col4" >m</th>
#         <th class="col_heading level0 col5" >n</th>
#         <th class="col_heading level0 col6" >p</th>
#         <th class="col_heading level0 col7" >s</th>
#         <th class="col_heading level0 col8" >y</th>
#         <th class="col_heading level0 col9" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2b5bc7ee_053d_11e8_8216_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col0" class="data row0 col0" >4.92%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col1" class="data row0 col1" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col2" class="data row0 col2" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col3" class="data row0 col3" >4.92%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col4" class="data row0 col4" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col5" class="data row0 col5" >41.95%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col6" class="data row0 col6" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col7" class="data row0 col7" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col8" class="data row0 col8" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow0_col9" class="data row0 col9" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2b5bc7ee_053d_11e8_8216_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col0" class="data row1 col0" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col1" class="data row1 col1" >2.36%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col2" class="data row1 col2" >26.59%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col3" class="data row1 col3" >0.00%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col4" class="data row1 col4" >0.44%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col5" class="data row1 col5" >1.48%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col6" class="data row1 col6" >3.15%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col7" class="data row1 col7" >7.09%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col8" class="data row1 col8" >7.09%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow1_col9" class="data row1 col9" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2b5bc7ee_053d_11e8_8216_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col0" class="data row2 col0" >4.92%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col1" class="data row2 col1" >2.36%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col2" class="data row2 col2" >26.59%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col3" class="data row2 col3" >4.92%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col4" class="data row2 col4" >0.44%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col5" class="data row2 col5" >43.43%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col6" class="data row2 col6" >3.15%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col7" class="data row2 col7" >7.09%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col8" class="data row2 col8" >7.09%</td>
#         <td id="T_2b5bc7ee_053d_11e8_8216_f82819a014barow2_col9" class="data row2 col9" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# gill-attachment(ひだのつき方)
# a:直性, d:垂性, f:離生, n:湾生,
# *========================================================================*
# gill-attachment    a     f   All
# class
# e                192  4016  4208
# p                 18  3898  3916
# All              210  7914  8124
# <style  type="text/css" >
# </style>
# <table id="T_2b7f0bde_053d_11e8_8a33_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >gill-attachment</th>
#         <th class="col_heading level0 col0" >a</th>
#         <th class="col_heading level0 col1" >f</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2b7f0bde_053d_11e8_8a33_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow0_col0" class="data row0 col0" >2.36%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow0_col1" class="data row0 col1" >49.43%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow0_col2" class="data row0 col2" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2b7f0bde_053d_11e8_8a33_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow1_col0" class="data row1 col0" >0.22%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow1_col1" class="data row1 col1" >47.98%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow1_col2" class="data row1 col2" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2b7f0bde_053d_11e8_8a33_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow2_col0" class="data row2 col0" >2.58%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow2_col1" class="data row2 col1" >97.42%</td>
#         <td id="T_2b7f0bde_053d_11e8_8a33_f82819a014barow2_col2" class="data row2 col2" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# gill-spacing(ひだの間隔)
# c:近い, w:密な, d:遠い,
# *========================================================================*
# gill-spacing     c     w   All
# class
# e             3008  1200  4208
# p             3804   112  3916
# All           6812  1312  8124
# <style  type="text/css" >
# </style>
# <table id="T_2b98ac48_053d_11e8_9ee6_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >gill-spacing</th>
#         <th class="col_heading level0 col0" >c</th>
#         <th class="col_heading level0 col1" >w</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2b98ac48_053d_11e8_9ee6_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow0_col0" class="data row0 col0" >37.03%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow0_col1" class="data row0 col1" >14.77%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow0_col2" class="data row0 col2" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2b98ac48_053d_11e8_9ee6_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow1_col0" class="data row1 col0" >46.82%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow1_col1" class="data row1 col1" >1.38%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow1_col2" class="data row1 col2" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2b98ac48_053d_11e8_9ee6_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow2_col0" class="data row2 col0" >83.85%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow2_col1" class="data row2 col1" >16.15%</td>
#         <td id="T_2b98ac48_053d_11e8_9ee6_f82819a014barow2_col2" class="data row2 col2" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# gill-size(ひだのサイズ)
# b:広い, n:狭い,
# *========================================================================*
# gill-size     b     n   All
# class
# e          3920   288  4208
# p          1692  2224  3916
# All        5612  2512  8124
# <style  type="text/css" >
# </style>
# <table id="T_2bb26046_053d_11e8_822b_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >gill-size</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >n</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2bb26046_053d_11e8_822b_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow0_col0" class="data row0 col0" >48.25%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow0_col1" class="data row0 col1" >3.55%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow0_col2" class="data row0 col2" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2bb26046_053d_11e8_822b_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow1_col0" class="data row1 col0" >20.83%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow1_col1" class="data row1 col1" >27.38%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow1_col2" class="data row1 col2" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2bb26046_053d_11e8_822b_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow2_col0" class="data row2 col0" >69.08%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow2_col1" class="data row2 col1" >30.92%</td>
#         <td id="T_2bb26046_053d_11e8_822b_f82819a014barow2_col2" class="data row2 col2" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# gill-color(ひだの色)
# k:黒色, n:茶色, b:淡黄色, h:チョコレート色, g:灰色, r:緑色, o:オレンジ色, p:ピンク色, u:紫色, e:赤色, w:白色, y:黄色,
# *========================================================================*
# gill-color     b   e    g    h    k     n   o     p   r    u     w   y   All
# class
# e              0  96  248  204  344   936  64   852   0  444   956  64  4208
# p           1728   0  504  528   64   112   0   640  24   48   246  22  3916
# All         1728  96  752  732  408  1048  64  1492  24  492  1202  86  8124
# <style  type="text/css" >
# </style>
# <table id="T_2bcffb5e_053d_11e8_8922_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >gill-color</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >e</th>
#         <th class="col_heading level0 col2" >g</th>
#         <th class="col_heading level0 col3" >h</th>
#         <th class="col_heading level0 col4" >k</th>
#         <th class="col_heading level0 col5" >n</th>
#         <th class="col_heading level0 col6" >o</th>
#         <th class="col_heading level0 col7" >p</th>
#         <th class="col_heading level0 col8" >r</th>
#         <th class="col_heading level0 col9" >u</th>
#         <th class="col_heading level0 col10" >w</th>
#         <th class="col_heading level0 col11" >y</th>
#         <th class="col_heading level0 col12" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2bcffb5e_053d_11e8_8922_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col0" class="data row0 col0" >0.00%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col1" class="data row0 col1" >1.18%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col2" class="data row0 col2" >3.05%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col3" class="data row0 col3" >2.51%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col4" class="data row0 col4" >4.23%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col5" class="data row0 col5" >11.52%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col6" class="data row0 col6" >0.79%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col7" class="data row0 col7" >10.49%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col8" class="data row0 col8" >0.00%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col9" class="data row0 col9" >5.47%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col10" class="data row0 col10" >11.77%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col11" class="data row0 col11" >0.79%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow0_col12" class="data row0 col12" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2bcffb5e_053d_11e8_8922_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col0" class="data row1 col0" >21.27%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col1" class="data row1 col1" >0.00%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col2" class="data row1 col2" >6.20%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col3" class="data row1 col3" >6.50%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col4" class="data row1 col4" >0.79%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col5" class="data row1 col5" >1.38%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col6" class="data row1 col6" >0.00%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col7" class="data row1 col7" >7.88%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col8" class="data row1 col8" >0.30%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col9" class="data row1 col9" >0.59%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col10" class="data row1 col10" >3.03%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col11" class="data row1 col11" >0.27%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow1_col12" class="data row1 col12" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2bcffb5e_053d_11e8_8922_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col0" class="data row2 col0" >21.27%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col1" class="data row2 col1" >1.18%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col2" class="data row2 col2" >9.26%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col3" class="data row2 col3" >9.01%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col4" class="data row2 col4" >5.02%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col5" class="data row2 col5" >12.90%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col6" class="data row2 col6" >0.79%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col7" class="data row2 col7" >18.37%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col8" class="data row2 col8" >0.30%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col9" class="data row2 col9" >6.06%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col10" class="data row2 col10" >14.80%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col11" class="data row2 col11" >1.06%</td>
#         <td id="T_2bcffb5e_053d_11e8_8922_f82819a014barow2_col12" class="data row2 col12" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# stalk-shape(柄の形状)
# e:先太型, t:先細型,
# *========================================================================*
# stalk-shape     e     t   All
# class
# e            1616  2592  4208
# p            1900  2016  3916
# All          3516  4608  8124
# <style  type="text/css" >
# </style>
# <table id="T_2bf9713a_053d_11e8_983e_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >stalk-shape</th>
#         <th class="col_heading level0 col0" >e</th>
#         <th class="col_heading level0 col1" >t</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2bf9713a_053d_11e8_983e_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow0_col0" class="data row0 col0" >19.89%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow0_col1" class="data row0 col1" >31.91%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow0_col2" class="data row0 col2" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2bf9713a_053d_11e8_983e_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow1_col0" class="data row1 col0" >23.39%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow1_col1" class="data row1 col1" >24.82%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow1_col2" class="data row1 col2" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2bf9713a_053d_11e8_983e_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow2_col0" class="data row2 col0" >43.28%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow2_col1" class="data row2 col1" >56.72%</td>
#         <td id="T_2bf9713a_053d_11e8_983e_f82819a014barow2_col2" class="data row2 col2" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# stalk-root(柄の根本)
# b:球根状, c:棍棒状, u:カップ状, e:扁平状, z:根状菌糸束, r:根状, ?:欠損値,
# *========================================================================*
# stalk-root     ?     b    c     e    r   All
# class
# e            720  1920  512   864  192  4208
# p           1760  1856   44   256    0  3916
# All         2480  3776  556  1120  192  8124
# <style  type="text/css" >
# </style>
# <table id="T_2c170bf4_053d_11e8_9280_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >stalk-root</th>
#         <th class="col_heading level0 col0" >?</th>
#         <th class="col_heading level0 col1" >b</th>
#         <th class="col_heading level0 col2" >c</th>
#         <th class="col_heading level0 col3" >e</th>
#         <th class="col_heading level0 col4" >r</th>
#         <th class="col_heading level0 col5" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2c170bf4_053d_11e8_9280_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col0" class="data row0 col0" >8.86%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col1" class="data row0 col1" >23.63%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col2" class="data row0 col2" >6.30%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col3" class="data row0 col3" >10.64%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col4" class="data row0 col4" >2.36%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow0_col5" class="data row0 col5" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2c170bf4_053d_11e8_9280_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col0" class="data row1 col0" >21.66%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col1" class="data row1 col1" >22.85%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col2" class="data row1 col2" >0.54%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col3" class="data row1 col3" >3.15%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col4" class="data row1 col4" >0.00%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow1_col5" class="data row1 col5" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2c170bf4_053d_11e8_9280_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col0" class="data row2 col0" >30.53%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col1" class="data row2 col1" >46.48%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col2" class="data row2 col2" >6.84%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col3" class="data row2 col3" >13.79%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col4" class="data row2 col4" >2.36%</td>
#         <td id="T_2c170bf4_053d_11e8_9280_f82819a014barow2_col5" class="data row2 col5" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# stalk-surface-above-ring(柄の表面(つばの上方部))
# f:繊維状, y:鱗片状, k:絹状, s:平滑状,
# *========================================================================*
# stalk-surface-above-ring    f     k     s   y   All
# class
# e                         408   144  3640  16  4208
# p                         144  2228  1536   8  3916
# All                       552  2372  5176  24  8124
# <style  type="text/css" >
# </style>
# <table id="T_2c3e84f4_053d_11e8_bcd6_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >stalk-surface-above-ring</th>
#         <th class="col_heading level0 col0" >f</th>
#         <th class="col_heading level0 col1" >k</th>
#         <th class="col_heading level0 col2" >s</th>
#         <th class="col_heading level0 col3" >y</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2c3e84f4_053d_11e8_bcd6_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow0_col0" class="data row0 col0" >5.02%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow0_col1" class="data row0 col1" >1.77%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow0_col2" class="data row0 col2" >44.81%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow0_col3" class="data row0 col3" >0.20%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow0_col4" class="data row0 col4" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2c3e84f4_053d_11e8_bcd6_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow1_col0" class="data row1 col0" >1.77%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow1_col1" class="data row1 col1" >27.42%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow1_col2" class="data row1 col2" >18.91%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow1_col3" class="data row1 col3" >0.10%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow1_col4" class="data row1 col4" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2c3e84f4_053d_11e8_bcd6_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow2_col0" class="data row2 col0" >6.79%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow2_col1" class="data row2 col1" >29.20%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow2_col2" class="data row2 col2" >63.71%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow2_col3" class="data row2 col3" >0.30%</td>
#         <td id="T_2c3e84f4_053d_11e8_bcd6_f82819a014barow2_col4" class="data row2 col4" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# stalk-surface-below-ring(柄の表面(つばの下方部))
# f:繊維状, y:鱗片状, k:絹状, s:平滑状,
# *========================================================================*
# stalk-surface-below-ring    f     k     s    y   All
# class
# e                         456   144  3400  208  4208
# p                         144  2160  1536   76  3916
# All                       600  2304  4936  284  8124
# <style  type="text/css" >
# </style>
# <table id="T_2c6054d2_053d_11e8_b1e3_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >stalk-surface-below-ring</th>
#         <th class="col_heading level0 col0" >f</th>
#         <th class="col_heading level0 col1" >k</th>
#         <th class="col_heading level0 col2" >s</th>
#         <th class="col_heading level0 col3" >y</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2c6054d2_053d_11e8_b1e3_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow0_col0" class="data row0 col0" >5.61%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow0_col1" class="data row0 col1" >1.77%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow0_col2" class="data row0 col2" >41.85%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow0_col3" class="data row0 col3" >2.56%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow0_col4" class="data row0 col4" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2c6054d2_053d_11e8_b1e3_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow1_col0" class="data row1 col0" >1.77%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow1_col1" class="data row1 col1" >26.59%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow1_col2" class="data row1 col2" >18.91%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow1_col3" class="data row1 col3" >0.94%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow1_col4" class="data row1 col4" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2c6054d2_053d_11e8_b1e3_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow2_col0" class="data row2 col0" >7.39%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow2_col1" class="data row2 col1" >28.36%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow2_col2" class="data row2 col2" >60.76%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow2_col3" class="data row2 col3" >3.50%</td>
#         <td id="T_2c6054d2_053d_11e8_b1e3_f82819a014barow2_col4" class="data row2 col4" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# stalk-color-above-ring(柄の色(つばの上方部))
# n:茶色, b:淡黄色, c:シナモン色, g:灰色, o:オレンジ色, p:ピンク色, e:赤色, w:白色, y:黄色,
# *========================================================================*
# stalk-color-above-ring    b   c   e    g    n    o     p     w  y   All
# class
# e                         0   0  96  576   16  192   576  2752  0  4208
# p                       432  36   0    0  432    0  1296  1712  8  3916
# All                     432  36  96  576  448  192  1872  4464  8  8124
# <style  type="text/css" >
# </style>
# <table id="T_2c7f8ad8_053d_11e8_a996_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >stalk-color-above-ring</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >c</th>
#         <th class="col_heading level0 col2" >e</th>
#         <th class="col_heading level0 col3" >g</th>
#         <th class="col_heading level0 col4" >n</th>
#         <th class="col_heading level0 col5" >o</th>
#         <th class="col_heading level0 col6" >p</th>
#         <th class="col_heading level0 col7" >w</th>
#         <th class="col_heading level0 col8" >y</th>
#         <th class="col_heading level0 col9" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2c7f8ad8_053d_11e8_a996_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col0" class="data row0 col0" >0.00%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col1" class="data row0 col1" >0.00%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col2" class="data row0 col2" >1.18%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col3" class="data row0 col3" >7.09%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col4" class="data row0 col4" >0.20%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col5" class="data row0 col5" >2.36%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col6" class="data row0 col6" >7.09%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col7" class="data row0 col7" >33.87%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col8" class="data row0 col8" >0.00%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow0_col9" class="data row0 col9" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2c7f8ad8_053d_11e8_a996_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow1_col0" class="data row1 col0" >5.32%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow1_col1" class="data row1 col1" >0.44%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow1_col2" class="data row1 col2" >0.00%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow1_col3" class="data row1 col3" >0.00%</td>
#         <td id="T_2c7f8ad8_053d_11e8_a996_f82819a014barow1_col4" class="data row1 col4" >5.32%</td>
# ...
#         <th class="col_heading level0 col3" >n</th>
#         <th class="col_heading level0 col4" >p</th>
#         <th class="col_heading level0 col5" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2d269db6_053d_11e8_9104_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col0" class="data row0 col0" >12.41%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col1" class="data row0 col1" >0.59%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col2" class="data row0 col2" >0.00%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col3" class="data row0 col3" >0.00%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col4" class="data row0 col4" >38.80%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow0_col5" class="data row0 col5" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2d269db6_053d_11e8_9104_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col0" class="data row1 col0" >21.76%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col1" class="data row1 col1" >0.00%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col2" class="data row1 col2" >15.95%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col3" class="data row1 col3" >0.44%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col4" class="data row1 col4" >10.04%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow1_col5" class="data row1 col5" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2d269db6_053d_11e8_9104_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col0" class="data row2 col0" >34.17%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col1" class="data row2 col1" >0.59%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col2" class="data row2 col2" >15.95%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col3" class="data row2 col3" >0.44%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col4" class="data row2 col4" >48.84%</td>
#         <td id="T_2d269db6_053d_11e8_9104_f82819a014barow2_col5" class="data row2 col5" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# spore-print-color(胞子紋の色)
# k:黒色, n:茶色, b:淡黄色, h:チョコレート色, r:緑色, o:オレンジ色, u:紫色, w:白色, y:黄色,
# *========================================================================*
# spore-print-color   b     h     k     n   o   r   u     w   y   All
# class
# e                  48    48  1648  1744  48   0  48   576  48  4208
# p                   0  1584   224   224   0  72   0  1812   0  3916
# All                48  1632  1872  1968  48  72  48  2388  48  8124
# <style  type="text/css" >
# </style>
# <table id="T_2d460e80_053d_11e8_b185_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >spore-print-color</th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >h</th>
#         <th class="col_heading level0 col2" >k</th>
#         <th class="col_heading level0 col3" >n</th>
#         <th class="col_heading level0 col4" >o</th>
#         <th class="col_heading level0 col5" >r</th>
#         <th class="col_heading level0 col6" >u</th>
#         <th class="col_heading level0 col7" >w</th>
#         <th class="col_heading level0 col8" >y</th>
#         <th class="col_heading level0 col9" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2d460e80_053d_11e8_b185_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col0" class="data row0 col0" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col1" class="data row0 col1" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col2" class="data row0 col2" >20.29%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col3" class="data row0 col3" >21.47%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col4" class="data row0 col4" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col5" class="data row0 col5" >0.00%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col6" class="data row0 col6" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col7" class="data row0 col7" >7.09%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col8" class="data row0 col8" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow0_col9" class="data row0 col9" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2d460e80_053d_11e8_b185_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col0" class="data row1 col0" >0.00%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col1" class="data row1 col1" >19.50%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col2" class="data row1 col2" >2.76%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col3" class="data row1 col3" >2.76%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col4" class="data row1 col4" >0.00%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col5" class="data row1 col5" >0.89%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col6" class="data row1 col6" >0.00%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col7" class="data row1 col7" >22.30%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col8" class="data row1 col8" >0.00%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow1_col9" class="data row1 col9" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2d460e80_053d_11e8_b185_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col0" class="data row2 col0" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col1" class="data row2 col1" >20.09%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col2" class="data row2 col2" >23.04%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col3" class="data row2 col3" >24.22%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col4" class="data row2 col4" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col5" class="data row2 col5" >0.89%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col6" class="data row2 col6" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col7" class="data row2 col7" >29.39%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col8" class="data row2 col8" >0.59%</td>
#         <td id="T_2d460e80_053d_11e8_b185_f82819a014barow2_col9" class="data row2 col9" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# population(集団形成)
# a:豊富, c:群生, n:多数, s:散在, v:少数, y:単性,
# *========================================================================*
# population    a    c    n     s     v     y   All
# class
# e           384  288  400   880  1192  1064  4208
# p             0   52    0   368  2848   648  3916
# All         384  340  400  1248  4040  1712  8124
# <style  type="text/css" >
# </style>
# <table id="T_2d6aed9e_053d_11e8_a026_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >population</th>
#         <th class="col_heading level0 col0" >a</th>
#         <th class="col_heading level0 col1" >c</th>
#         <th class="col_heading level0 col2" >n</th>
#         <th class="col_heading level0 col3" >s</th>
#         <th class="col_heading level0 col4" >v</th>
#         <th class="col_heading level0 col5" >y</th>
#         <th class="col_heading level0 col6" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2d6aed9e_053d_11e8_a026_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col0" class="data row0 col0" >4.73%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col1" class="data row0 col1" >3.55%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col2" class="data row0 col2" >4.92%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col3" class="data row0 col3" >10.83%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col4" class="data row0 col4" >14.67%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col5" class="data row0 col5" >13.10%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow0_col6" class="data row0 col6" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2d6aed9e_053d_11e8_a026_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col0" class="data row1 col0" >0.00%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col1" class="data row1 col1" >0.64%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col2" class="data row1 col2" >0.00%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col3" class="data row1 col3" >4.53%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col4" class="data row1 col4" >35.06%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col5" class="data row1 col5" >7.98%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow1_col6" class="data row1 col6" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2d6aed9e_053d_11e8_a026_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col0" class="data row2 col0" >4.73%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col1" class="data row2 col1" >4.19%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col2" class="data row2 col2" >4.92%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col3" class="data row2 col3" >15.36%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col4" class="data row2 col4" >49.73%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col5" class="data row2 col5" >21.07%</td>
#         <td id="T_2d6aed9e_053d_11e8_a026_f82819a014barow2_col6" class="data row2 col6" >100.00%</td>
#     </tr></tbody>
# </table>
# *========================================================================*
# habitat(生息地)
# g:芝生, l:葉, m:牧草地, p:道路, u:都市部, w:廃棄物, d:木,
# *========================================================================*
# habitat     d     g    l    m     p    u    w   All
# class
# e        1880  1408  240  256   136   96  192  4208
# p        1268   740  592   36  1008  272    0  3916
# All      3148  2148  832  292  1144  368  192  8124
# <style  type="text/css" >
# </style>
# <table id="T_2d8bf99e_053d_11e8_8bcd_f82819a014ba" >
# <thead>    <tr>
#         <th class="index_name level0" >habitat</th>
#         <th class="col_heading level0 col0" >d</th>
#         <th class="col_heading level0 col1" >g</th>
#         <th class="col_heading level0 col2" >l</th>
#         <th class="col_heading level0 col3" >m</th>
#         <th class="col_heading level0 col4" >p</th>
#         <th class="col_heading level0 col5" >u</th>
#         <th class="col_heading level0 col6" >w</th>
#         <th class="col_heading level0 col7" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >class</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2d8bf99e_053d_11e8_8bcd_f82819a014balevel0_row0" class="row_heading level0 row0" >e</th>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col0" class="data row0 col0" >23.14%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col1" class="data row0 col1" >17.33%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col2" class="data row0 col2" >2.95%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col3" class="data row0 col3" >3.15%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col4" class="data row0 col4" >1.67%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col5" class="data row0 col5" >1.18%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col6" class="data row0 col6" >2.36%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow0_col7" class="data row0 col7" >51.80%</td>
#     </tr>    <tr>
#         <th id="T_2d8bf99e_053d_11e8_8bcd_f82819a014balevel0_row1" class="row_heading level0 row1" >p</th>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col0" class="data row1 col0" >15.61%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col1" class="data row1 col1" >9.11%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col2" class="data row1 col2" >7.29%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col3" class="data row1 col3" >0.44%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col4" class="data row1 col4" >12.41%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col5" class="data row1 col5" >3.35%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col6" class="data row1 col6" >0.00%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow1_col7" class="data row1 col7" >48.20%</td>
#     </tr>    <tr>
#         <th id="T_2d8bf99e_053d_11e8_8bcd_f82819a014balevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col0" class="data row2 col0" >38.75%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col1" class="data row2 col1" >26.44%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col2" class="data row2 col2" >10.24%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col3" class="data row2 col3" >3.59%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col4" class="data row2 col4" >14.08%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col5" class="data row2 col5" >4.53%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col6" class="data row2 col6" >2.36%</td>
#         <td id="T_2d8bf99e_053d_11e8_8bcd_f82819a014barow2_col7" class="data row2 col7" >100.00%</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### 説明変数の順位付け
# 現時点では、識別にどのアルゴリズムを利用するか決めてないので、<br>
# 各属性要素が毒キノコである確率の平均情報量（エントロピー）で順位付けしてみます。<br>
# <br>
# 【エントロピー式】<br>
# $H(X) = -\sum_{i}P_ilog(P_i)$　　($P_i$は$X=i$となる確率)<br>
# <br>

# %%
dict_entropy = {}
for col, df in dict_p.items():
    df = df.drop('All', axis=0)
    df = df.drop('All', axis=1)
    if col == 'stalk-root':
        df = df.drop('?', axis=1)
    entropy = 0
    for ind, row in df.iterrows():
        if ind == 'p':
            for p in row:
                if p != 0:
                    entropy -= p * np.log(p)
    dict_entropy[col] = entropy

df_e = pd.DataFrame(dict_entropy, index=['entropy']).T
display(df_e.sort_values(by=['entropy'], ascending=False))
# Out:
#                            entropy
# cap-color                 1.184697
# gill-color                1.146196
# habitat                   1.095667
# odor                      1.011222
# stalk-color-below-ring    0.975778
# stalk-color-above-ring    0.963848
# spore-print-color         0.893322
# ring-type                 0.879542
# cap-shape                 0.870925
# cap-surface               0.859561
# stalk-surface-below-ring  0.782322
# stalk-surface-above-ring  0.748022
# population                0.741669
# stalk-shape               0.685666
# gill-size                 0.681416
# bruises                   0.563171
# stalk-root                0.474508
# ring-number               0.421066
# gill-spacing              0.414350
# gill-attachment           0.365897
# veil-color                0.358844
# veil-type                 0.351761

# %% [markdown]
# <b>
# 情報量視点では、'cap-color(かさの色)'がキノコが毒と判別する情報量が大きいみたいです。
# </b>
